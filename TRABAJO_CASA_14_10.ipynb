# %% [markdown]
# <a href="https://colab.research.google.com/github/mjaimes619/FUNPRO/blob/main/TRABAJO_CASA_14_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imagen de WhatsApp 2025-10-14 a las 22.48.57_91c8f4ba.jpg](data:image/jpeg;base64,...)
